# %%
import pandas as pd
import numpy as np

# %%
stock = pd.read_csv('stock_df.csv')

# %%
print(stock)
# Out:
#           Dates   AAPL.Open   AAPL.High    AAPL.Low  AAPL.Close  AAPL.Volume  \
# 0    2020-01-02   74.059998   75.150002   73.797501   75.087502  135480400.0
# 1    2020-01-03   74.287498   75.144997   74.125000   74.357498  146322800.0
# 2    2020-01-06   73.447502   74.989998   73.187500   74.949997  118387200.0
# 3    2020-01-07   74.959999   75.224998   74.370003   74.597504  108872000.0
# 4    2020-01-08   74.290001   76.110001   74.290001   75.797501  132079200.0
# ..          ...         ...         ...         ...         ...          ...
# 751  2022-12-23  130.919998  132.419998  129.639999  131.860001   63814900.0
# 752  2022-12-27  131.380005  131.410004  128.720001  130.029999   69007800.0
# 753  2022-12-28  129.669998  131.029999  125.870003  126.040001   85438400.0
# 754  2022-12-29  127.989998  130.479996  127.730003  129.610001   75703700.0
# 755  2022-12-30  128.410004  129.949997  127.430000  129.929993   77034200.0
#
#      AAPL.Adjusted  daily.returns
# ...

# %%
stock['Implied_Volatility'] = 0
stock
# Out:
#           Dates   AAPL.Open   AAPL.High    AAPL.Low  AAPL.Close  AAPL.Volume  \
# 0    2020-01-02   74.059998   75.150002   73.797501   75.087502  135480400.0
# 1    2020-01-03   74.287498   75.144997   74.125000   74.357498  146322800.0
# 2    2020-01-06   73.447502   74.989998   73.187500   74.949997  118387200.0
# 3    2020-01-07   74.959999   75.224998   74.370003   74.597504  108872000.0
# 4    2020-01-08   74.290001   76.110001   74.290001   75.797501  132079200.0
# ..          ...         ...         ...         ...         ...          ...
# 751  2022-12-23  130.919998  132.419998  129.639999  131.860001   63814900.0
# 752  2022-12-27  131.380005  131.410004  128.720001  130.029999   69007800.0
# 753  2022-12-28  129.669998  131.029999  125.870003  126.040001   85438400.0
# 754  2022-12-29  127.989998  130.479996  127.730003  129.610001   75703700.0
# 755  2022-12-30  128.410004  129.949997  127.430000  129.929993   77034200.0
#
# ...
